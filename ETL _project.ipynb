# 8   Finneas O'Connell, producer; Rob Kinelski & Fi...
# 9   Brad Cook, Chris Messina & Justin Vernon, prod...
# 10  Jack Antonoff & Lana Del Rey, producers; Jack ...
# 11  Tommy Brown, Ilya, Max Martin & Victoria Monet...
# 12  David "Swagg R'Celious" Harris, H.E.R., Walter...
# 13  Joe Grasso, engineer/mixer; Montero Lamar Hill...
# 14  Ricky Reed, producer; Manny Marroquin & Ethan ...
# 15  Ezra Koenig & Ariel Rechtshaid, producers; Joh...
# 16  Billie Eilish O'Connell & Finneas O'Connell, s...
# 17  Natalie Hemby, Lady Gaga, Hillary Lindsey & Lo...
# 18  Brandi Carlile, Phil Hanseroth, Tim Hanseroth ...
# 19  Ruby Amanfu, Sam Ashworth, D. Arcelious Harris...
# 20            Taylor Swift, songwriter (Taylor Swift)
# 21  Jack Antonoff & Lana Del Rey, songwriters (Lan...
# 22  Tom Barnes, Lewis Capaldi, Pete Kelleher, Benj...
# 23  Steven Cheung, Eric Frederic, Melissa Jefferso...
# 24                                                NaN
#
#                                                   img  winner
# 0   https://www.grammy.com/sites/com/files/styles/...    True
# 1   https://www.grammy.com/sites/com/files/styles/...    True
# 2   https://www.grammy.com/sites/com/files/styles/...    True
# 3   https://www.grammy.com/sites/com/files/styles/...    True
# 4   https://www.grammy.com/sites/com/files/styles/...    True
# 5   https://www.grammy.com/sites/com/files/styles/...    True
# 6   https://www.grammy.com/sites/com/files/styles/...    True
# 7   https://www.grammy.com/sites/com/files/styles/...    True
# 8   https://www.grammy.com/sites/com/files/styles/...    True
# 9   https://www.grammy.com/sites/com/files/styles/...    True
# 10  https://www.grammy.com/sites/com/files/styles/...    True
# 11  https://www.grammy.com/sites/com/files/styles/...    True
# 12  https://www.grammy.com/sites/com/files/styles/...    True
# 13  https://www.grammy.com/sites/com/files/styles/...    True
# 14  https://www.grammy.com/sites/com/files/styles/...    True
# 15  https://www.grammy.com/sites/com/files/styles/...    True
# 16  https://www.grammy.com/sites/com/files/styles/...    True
# 17  https://www.grammy.com/sites/com/files/styles/...    True
# 18  https://www.grammy.com/sites/com/files/styles/...    True
# 19  https://www.grammy.com/sites/com/files/styles/...    True
# 20  https://www.grammy.com/sites/com/files/styles/...    True
# 21  https://www.grammy.com/sites/com/files/styles/...    True
# 22  https://www.grammy.com/sites/com/files/styles/...    True
# 23  https://www.grammy.com/sites/com/files/styles/...    True
# 24                                                NaN    True

# %%
###Create new data w select columns

# %%
grammy_columns = ["nominee", "artist", "year", "title", "category"]
grammy_data = grammy_data_df[grammy_columns].copy()

grammy_df = grammy_data.rename(columns={"nominee": "song_title",
                                        "artist": "artist_name",
                                        "year": "award_year",
                                        "title": "award_title",
                                        "category": "award_category"})

grammy_df = grammy_df.dropna(how='any')
grammy_df = grammy_df.drop_duplicates(subset=["song_title", "artist_name"], inplace=False)


grammy_df
# Out:
#                               song_title  \
# 0                                Bad Guy
# 1                                Hey, Ma
# 2                                7 rings
# 3                             Hard Place
# 4                                   Talk
# ...                                  ...
# 4793                          Tom Dooley
# 4794                             Tequila
# 4801                                Gigi
# 4802  The Best Of The Stan Freberg Shows
# 4803                   The Chipmunk Song
#
#                                             artist_name  award_year  \
# 0                                         Billie Eilish        2019
# 1                                              Bon Iver        2019
# 2                                         Ariana Grande        2019
# 3                                                H.E.R.        2019
# 4                                                Khalid        2019
# ...                                                 ...         ...
# 4793                                  The Kingston Trio        1958
# 4794                                         The Champs        1958
# 4801                                       Andre Previn        1958
# 4802                                       Stan Freberg        1958
# 4803  David Seville And The Chipmunks (Ross Bagdasar...        1958
#
#                             award_title  \
# 0     62nd Annual GRAMMY Awards  (2019)
# 1     62nd Annual GRAMMY Awards  (2019)
# 2     62nd Annual GRAMMY Awards  (2019)
# 3     62nd Annual GRAMMY Awards  (2019)
# 4     62nd Annual GRAMMY Awards  (2019)
# ...                                 ...
# 4793   1st Annual GRAMMY Awards  (1958)
# 4794   1st Annual GRAMMY Awards  (1958)
# 4801   1st Annual GRAMMY Awards  (1958)
# 4802   1st Annual GRAMMY Awards  (1958)
# 4803   1st Annual GRAMMY Awards  (1958)
#
#                                          award_category
# 0                                    Record Of The Year
# 1                                    Record Of The Year
# 2                                    Record Of The Year
# 3                                    Record Of The Year
# 4                                    Record Of The Year
# ...                                                 ...
# 4793                 Best Country & Western Performance
# 4794                    Best Rhythm & Blues Performance
# 4801  Best Sound Track Album, Dramatic Picture Score...
# 4802       Best Performance, Documentary Or Spoken Word
# 4803                        Best Recording For Children
#
# [2841 rows x 5 columns]

# %%
song_info_df = grammy_df[["song_title", "artist_name"]].copy()




song_info_df.head()
# Out:
#    song_title    artist_name
# 0     Bad Guy  Billie Eilish
# 1     Hey, Ma       Bon Iver
# 2     7 rings  Ariana Grande
# 3  Hard Place         H.E.R.
# 4        Talk         Khalid

# %%
award_info_df = grammy_df[["award_title", "award_year", "song_title", "artist_name", "award_category"]].copy()
award_info_df.head()
# Out:
#                          award_title  award_year  song_title    artist_name  \
# 0  62nd Annual GRAMMY Awards  (2019)        2019     Bad Guy  Billie Eilish
# 1  62nd Annual GRAMMY Awards  (2019)        2019     Hey, Ma       Bon Iver
# 2  62nd Annual GRAMMY Awards  (2019)        2019     7 rings  Ariana Grande
# 3  62nd Annual GRAMMY Awards  (2019)        2019  Hard Place         H.E.R.
# 4  62nd Annual GRAMMY Awards  (2019)        2019        Talk         Khalid
#
#        award_category
# 0  Record Of The Year
# 1  Record Of The Year
# 2  Record Of The Year
# 3  Record Of The Year
# 4  Record Of The Year

# %%
spotify_data_df = pd.read_csv(spotify_data)
spotify_data_df.head(50)
# Out:
#     genre           artist_name  \
# 0   Movie        Henri Salvador
# 1   Movie     Martin & les fées
# 2   Movie       Joseph Williams
# 3   Movie        Henri Salvador
# 4   Movie          Fabien Nataf
# 5   Movie        Henri Salvador
# 6   Movie     Martin & les fées
# 7   Movie           Laura Mayne
# 8   Movie                Chorus
# 9   Movie   Le Club des Juniors
# 10  Movie     Leopold Stokowski
# 11  Movie          Randy Newman
# 12  Movie  Idoles De La Musique
# 13  Movie                Chorus
# 14  Movie    Richard M. Sherman
# 15  Movie           Michel Roux
# 16  Movie    Jean Claude Corbel
# 17  Movie         Bernard Minet
# 18  Movie        Henri Salvador
# 19  Movie                Amalya
# 20  Movie     Martin & les fées
# 21  Movie              Dorothée
# 22  Movie        Henri Salvador
# 23  Movie    Jean Claude Corbel
# 24  Movie        Henri Salvador
# 25  Movie             Jean Piat
# 26  Movie        Henri Salvador
# 27  Movie          Lucie Dolene
# 28  Movie        Henri Salvador
# 29  Movie                Chorus
# 30  Movie                Chorus
# 31  Movie     Martin & les fées
# 32  Movie        Henri Salvador
# 33  Movie        Henri Salvador
# 34  Movie                Chorus
# 35  Movie        Henri Salvador
# 36  Movie                Chorus
# 37  Movie        Henri Salvador
# 38  Movie    Richard M. Sherman
# 39  Movie           Larry Groce
# 40  Movie                Chorus
# 41  Movie     Leopold Stokowski
# 42  Movie        Henri Salvador
# 43  Movie         Patrick Rocca
# 44  Movie              Ken Page
# 45  Movie              Ken Page
# 46  Movie         Bernard Minet
# 47  Movie          Debbie Davis
# 48  Movie        Henri Salvador
# 49  Movie              Dorothée
#
#                                            track_name                track_id  \
# 0                         C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1                    Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2                      Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3                      Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                           Ouverture  0IuslXpMROHdEPvSl1fTQK
# 5                      Le petit souper aux chandelles  0Mf1jKa8eNAf1a4PwTbizj
# 6   Premières recherches (par Paul Ventimila, Lori...  0NUiKYRd6jt1LKMYGkUdnZ
# 7                                       Let Me Let Go  0PbIF9YVD505GutwotpB5C
# 8                                               Helka  0ST6uPfvaPpJLtQwhE6KfC
# 9                           Les bisous des bisounours  0VSqZ3KStsjcfERGdcWpFO
# 10  Symphony No.4 In E Minor Op.98 : IV. Allegro E...  0XKgegoxLcIihK3Klpfo3N
# 11  The Hanging (Maverick - Original Motion Pictur...  0hprxsuRM5vVCOfaM7l3gQ
# 12                             J'ai demandé à la lune  0jF6HUm18fg6QQCLHhfhC0
# 13                                      Mangala Aarti  0jIY0oRAp1T4mezDyEhOad
# 14                                       Keys of Love  0pXwl2CRP5awxHsF9eET3L
# 15       Les aventures d'Arsène Lupin: 813 - Partie 6  0uWUjxM7oDPKpb3T2y3oZm
# 16                                              Diane  0vS7Zid3q0dMyX8uMnlQ8s
# 17                                       Ultra Man 80  0x8xSaoSfQkOYUnG1nbga0
# 18                                            Veunise  113pHPsGwyeklEjLhnB3ZT
# 19                               Ladies And Gentlemen  12ZjoNweObu1k9rK4SOSdL
# 20  Tout est possible (par Anggun, Dany Brillant, ...  12hJJLMMbJDK0F9I3g5SLv
# 21                                     Clic clac cloc  148uA2Y78xfxDiCNjgZA0v
# 22                                 Monsieur Boum Boum  14K25Ks5fdHjHfpIYOTc4y
# 23                         Pourquoi aller plus loin ?  15CpJP0LXchBUjpB8RKh8m
# 24                            Quand je monte chez toi  15nBPcHoH2fZmRiFd2ZhMh
# 25                               Comme minuit sonnait  16UTNMhXjeJa8IG9uBijxZ
# 26                                          Le Fêtard  16hVzfu0IJZmP3Bj4x1BB1
# 27                             Le mariage des poupées  17c4utCC03TPtTHXw2EVGB
# 28                                  Une chanson douce  1J5pa9cW0uCsNrFwag0jDD
# 29                   Mangani – Do Banjare / Amba Heth  1KIKeCTNJKYpQK5X5Sqc1v
# 30                          A ty się śmiejesz ze mnie  1KVSUAEvXBSlARo03y4YYG
# 31  Une journée d'école qui s'achève (par Véroniqu...  1LFky4DBeOLzVWbg0avgod
# 32                                    C Est Le Be Bop  1R8nFU8no9yINDiCzBcgB3
# 33                                 La Samba De Là-Bas  1X8uhUgBKmotpvHrsS7fEe
# 34                           Ambarsare Diyan Warhiyan  1Zj5XBiUaHTkkBJ2nET477
# 35                                  Silence on tourne  1bo3gLD3Es261UYTfMLh4y
# 36                                       For the Game  1cAI02OznrXX5yrqonMCfh
# 37                            Quand un artiste - live  1dQKx8EJBbhHxc7qOgsBjb
# 38                                          Afterglow  1j6b29LbEnEqbn8aswj4p1
# 39                                   Sailing, Sailing  1jyknwZYTEEj1TCUozUbCi
# 40                               Tehni Pe Kisi Shajar  1lG8EIwGceFVRntJvA9hnY
# 41         Bourrée, From English Suite No. 2, BWV 807  1ppTRhpfunYl8Jd3Hfckee
# 42                                       La Vie grise  1py5dPKJVdQmXdZKjdvmwB
# 43                                 To Be or Not to Be  1q7DDr7riLHgrqAMxyZNFC
# 44                                  Dancing with Gene  1qCTyNzxGkFXnvdrqT5olw
# 45                              Penn Station - Seesaw  1qda3iYG5DlQJeY5BpSmpe
# 46                                     Dragon Ball GT  1wUjDOW0NXDBUPYPzNxczV
# 47                 I'll Feel Much Better When You Cry  23YuvN1cvAocACyKpYqzvu
# 48  La samba de là-bas (De l'opérette "Le Chevalie...  244U5mhlSmoudM4BMN25Wu
# 49                            J'ai retrouvé ma valise  24QIhmFU3ve4VIwDlBTtlp
#
#     popularity  acousticness  danceability  duration_ms  energy  \
# 0            0       0.61100         0.389        99373  0.9100
# 1            1       0.24600         0.590       137373  0.7370
# 2            3       0.95200         0.663       170267  0.1310
# 3            0       0.70300         0.240       152427  0.3260
# 4            4       0.95000         0.331        82625  0.2250
# 5            0       0.74900         0.578       160627  0.0948
# 6            2       0.34400         0.703       212293  0.2700
# 7           15       0.93900         0.416       240067  0.2690
# 8            0       0.00104         0.734       226200  0.4810
# 9           10       0.31900         0.598       152694  0.7050
# 10           0       0.92100         0.191       566960  0.1450
# 27            4/4   0.7280
# 28            4/4   0.9710
# 29            1/4   0.7560
# 30            4/4   0.8120
# 31            4/4   0.7510
# 32            4/4   0.7470
# 33            4/4   0.8580
# 34            4/4   0.9680
# 35            4/4   0.9080
# 36            4/4   0.6370
# 37            4/4   0.5690
# 38            3/4   0.1880
# 39            4/4   0.6180
# 40            4/4   0.8560
# 41            4/4   0.5480
# 42            4/4   0.2220
# 43            4/4   0.6910
# 44            3/4   0.4640
# 45            4/4   0.7350
# 46            4/4   0.6410
# 47            3/4   0.6160
# 48            4/4   0.9320
# 49            4/4   0.9110

# %%
### Clean DataFrame

# %%
spotify_columns = ["artist_name", "track_name", "popularity", "danceability", "energy", "acousticness", "instrumentalness", "track_id", "key"]
spotify_data = spotify_data_df[spotify_columns].copy()

spotify_df = spotify_data.rename(columns={"track_name": "song_title"})



spotify_df.head()
# Out:
#          artist_name                        song_title  popularity  \
# 0     Henri Salvador       C'est beau de faire un Show           0
# 1  Martin & les fées  Perdu d'avance (par Gad Elmaleh)           1
# 2    Joseph Williams    Don't Let Me Be Lonely Tonight           3
# 3     Henri Salvador    Dis-moi Monsieur Gordon Cooper           0
# 4       Fabien Nataf                         Ouverture           4
#
#    danceability  energy  acousticness  instrumentalness  \
# 0         0.389   0.910         0.611             0.000
# 1         0.590   0.737         0.246             0.000
# 2         0.663   0.131         0.952             0.000
# 3         0.240   0.326         0.703             0.000
# 4         0.331   0.225         0.950             0.123
#
#                  track_id key
# 0  0BRjO6ga9RKCKjfDqeFgWV  C#
# 1  0BjC1NfoEOOusryehmNudP  F#
# 2  0CoSDzoNIKCRs124s9uTVy   C
# 3  0Gc6TVm52BwZD07Ki6tIvf  C#
# 4  0IuslXpMROHdEPvSl1fTQK   F

# %%
###Connect to local database

# %%
rds_connection_string = "postgres:bootcamp@localhost:5432/music_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
###Check for tables

# %%
engine.table_names()
# Out:
# <ipython-input-10-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['song_info', 'award_info', 'spotify_data']

# %%
### Use pandas to load DataFrames into database

# %%
song_info_df.to_sql(name='song_info', con=engine, if_exists='append', index=False)

# %%
award_info_df.to_sql(name='award_info', con=engine, if_exists='append', index=False)

# %%
spotify_df.to_sql(name='spotify_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1288         parts[-1:] = post
# -> 1289         cur.execute(b''.join(parts))
#    1290         if fetch:
#
# ForeignKeyViolation: insert or update on table "spotify_data" violates foreign key constraint "fk_spotify_data_artist_name_song_title"
# DETAIL:  Key (artist_name, song_title)=(Henri Salvador, C'est beau de faire un Show) is not present in table "song_info".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-15-c2237ce80af8> in <module>
# ----> 1 spotify_df.to_sql(name='spotify_data', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1683                             break
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#    1687                     )
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     901                 kwargs = {}
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#     905                 statement,
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1287             parts.append(b',')
#    1288         parts[-1:] = post
# -> 1289         cur.execute(b''.join(parts))
#    1290         if fetch:
#    1291             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "spotify_data" violates foreign key constraint "fk_spotify_data_artist_name_song_title"
# DETAIL:  Key (artist_name, song_title)=(Henri Salvador, C'est beau de faire un Show) is not present in table "song_info".
#
# [SQL: INSERT INTO spotify_data (artist_name, song_title, popularity, danceability, energy, acousticness, instrumentalness, track_id, key) VALUES (%(artist_name)s, %(song_title)s, %(popularity)s, %(danceability)s, %(energy)s, %(acousticness)s, %(instrumentalness)s, %(track_id)s, %(key)s)]
# [parameters: ({'artist_name': 'Henri Salvador', 'song_title': "C'est beau de faire un Show", 'popularity': 0, 'danceability': 0.389, 'energy': 0.91, 'acousticness': 0.611, 'instrumentalness': 0.0, 'track_id': '0BRjO6ga9RKCKjfDqeFgWV', 'key': 'C#'}, {'artist_name': 'Martin & les fées', 'song_title': "Perdu d'avance (par Gad Elmaleh)", 'popularity': 1, 'danceability': 0.59, 'energy': 0.737, 'acousticness': 0.246, 'instrumentalness': 0.0, 'track_id': '0BjC1NfoEOOusryehmNudP', 'key': 'F#'}, {'artist_name': 'Joseph Williams', 'song_title': "Don't Let Me Be Lonely Tonight", 'popularity': 3, 'danceability': 0.663, 'energy': 0.131, 'acousticness': 0.952, 'instrumentalness': 0.0, 'track_id': '0CoSDzoNIKCRs124s9uTVy', 'key': 'C'}, {'artist_name': 'Henri Salvador', 'song_title': 'Dis-moi Monsieur Gordon Cooper', 'popularity': 0, 'danceability': 0.24, 'energy': 0.326, 'acousticness': 0.703, 'instrumentalness': 0.0, 'track_id': '0Gc6TVm52BwZD07Ki6tIvf', 'key': 'C#'}, {'artist_name': 'Fabien Nataf', 'song_title': 'Ouverture', 'popularity': 4, 'danceability': 0.331, 'energy': 0.225, 'acousticness': 0.95, 'instrumentalness': 0.123, 'track_id': '0IuslXpMROHdEPvSl1fTQK', 'key': 'F'}, {'artist_name': 'Henri Salvador', 'song_title': 'Le petit souper aux chandelles', 'popularity': 0, 'danceability': 0.578, 'energy': 0.0948, 'acousticness': 0.749, 'instrumentalness': 0.0, 'track_id': '0Mf1jKa8eNAf1a4PwTbizj', 'key': 'C#'}, {'artist_name': 'Martin & les fées', 'song_title': 'Premières recherches (par Paul Ventimila, Lorie Pester, Véronique Jannot, Michèle Laroque & Gérard Lenorman)', 'popularity': 2, 'danceability': 0.703, 'energy': 0.27, 'acousticness': 0.344, 'instrumentalness': 0.0, 'track_id': '0NUiKYRd6jt1LKMYGkUdnZ', 'key': 'C#'}, {'artist_name': 'Laura Mayne', 'song_title': 'Let Me Let Go', 'popularity': 15, 'danceability': 0.416, 'energy': 0.269, 'acousticness': 0.939, 'instrumentalness': 0.0, 'track_id': '0PbIF9YVD505GutwotpB5C', 'key': 'F#'}  ... displaying 10 of 232725 total bound parameter sets ...  {'artist_name': 'R.LUM.R', 'song_title': 'With My Words', 'popularity': 44, 'danceability': 0.745, 'energy': 0.704, 'acousticness': 0.262, 'instrumentalness': 0.0, 'track_id': '6EFsue2YbIG4Qkq8Zr9Rir', 'key': 'A'}, {'artist_name': 'Mint Condition', 'song_title': "You Don't Have To Hurt No More", 'popularity': 35, 'danceability': 0.758, 'energy': 0.47, 'acousticness': 0.0973, 'instrumentalness': 4.89e-05, 'track_id': '34XO9RwPMKjbvRry54QzWn', 'key': 'G#'})]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %%
### Use pandas to load json converted DataFrame into database

# %%
### Confirm data has been added by querying the customer_name table

# %%
pd.read_sql_query('select * XYZ_123', con=engine).head()

# %%
### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from ABC_123', con=engine).head()
